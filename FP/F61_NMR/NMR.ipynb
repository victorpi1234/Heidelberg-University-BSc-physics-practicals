# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob

# %%
# Get all matching files
files = glob.glob("chem_shift_*")

plt.figure(figsize=(10, 6))

# Loop through files
for file in files:
    # Read and parse the file
    data = pd.read_csv(file, skiprows=1, delimiter="\t", header=None, decimal=",")
    x = data[0]
    y = data[1]

    # Use only the filename (without path) as the label
    label = os.path.basename(file)
    plt.plot(x, y, label=label)

plt.title("Chemical Shift Data")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude [a.u.]")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("Chem_shift.pdf")
plt.show()

# %%
# Loop through files and create individual plots
for file in files:
    # Read and parse the file
    data = pd.read_csv(file, skiprows=1, delimiter="\t", header=None, decimal=",")
    x = data[0]
    y = data[1]
    
    # Create a new figure for each file
    plt.figure(figsize=(8, 5))
    label = os.path.basename(file)

    plt.plot(x, y, label=label)
    plt.title(f"Chemical Shift - {label}")
    plt.xlabel("Frequency [Hz]")
    plt.ylabel("Amplitude [a.u.]")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Optional: Save the figure
    # plt.savefig(f"{label}.png", dpi=300)

    plt.show()

# %%
# Files to plot
files = ["chem_shift_E", "chem_shift_E+"]

plt.figure(figsize=(10, 6))

for file in files:
    data = pd.read_csv(file, skiprows=1, delimiter="\t", header=None, decimal=",")
    x = data[0]
    y = data[1]
    plt.plot(x, y, label=file)

plt.title("Chemical Shift - E and E+")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude [a.u.]")
plt.xticks(range(0, int(x.max()) + 1, 100))  # Tick every 100 Hz
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()
